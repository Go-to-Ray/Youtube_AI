# %% [markdown]
# # k-means(k平均法)のPythonによるフルスクラッチ

# %% [markdown]
# ### アルゴリズムの実態
#
# 0. kを決める
# 1. 初期値をk個決定する
# 2. 重心に近い点を決定する
# 3. それぞれの重心にそれぞれの重心を移動する（パワーワード感）
# 4. 2~3.を繰り返す
# 5. kを変更して1に戻る

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## ダミーデータを作成する

# %%
n_data0 = 20             #1.データの数
n_data1 = 20
n_data2 = 20

mean0 = [1, 4]          #2.データ０における平均値（ｘ、ｙ）
mean1 = [1.8, 2]
mean2 = [1.4, 1]
noise = [[0.8, 2.2],
         [3.0, 0.7]]


cov0  = [[0.04, 0.0],
         [0.0, 0.04]]    #3.データ０における共分散行列
cov1  = [[0.04, 0.0],
         [0.0, 0.04]]
cov2  = [[0.04, 0.0],
         [0.0, 0.04]]


#二次元正規分布を生成する（0~3の値によって変動する）
X0 = np.random.multivariate_normal(mean0, cov0, n_data0)
X1 = np.random.multivariate_normal(mean1, cov1, n_data1)
X2 = np.random.multivariate_normal(mean2, cov2, n_data2)

#それぞれのデータの結合
X = np.concatenate((X0, X1, X2, noise))

plt.scatter(X[:,0],X[:,1],)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
k = 2

#center = np.array([[np.min(X[:,i])+np.random.rand()*(np.max(X[:,i])-np.min(X[:,i])) for i in range(X.shape[1])] for i in range(k)])
center_i = np.arange(0,X.shape[0])
center = X[np.random.choice(center_i,k),:]



plt.scatter(X[:,0], X[:,1])
plt.scatter(center[:,0], center[:,1],s=10,c="r")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
class kmeans():
    def __init__(self,plus=False):
        self.plus = plus
        
    def clustering(self,k):
        dist_list = [0]*k
        for c in range(k):
            dist_list[c] = np.sum((self.X-self.center[c])**2,axis=1)
            
        self.cluster = np.argmin(np.array(dist_list),axis=0)
    
    #fiding centers
    def fit(self,X):
        self.X = X
        n_sample = X.shape[0]
        
        #alter n_cluster
        for k in range(2,X.shape[0]-5):
            if self.plus == False:
                self.center = X[np.random.choice(np.arange(0,n_sample),k),:]
            else:
                distance = np.zeros((n,k))
                #最初の重心決定確率は一律
                pr = np.ones(n)/n
                for c in range(k-1):
                    flag = True
                    while flag:
                        #重心決定
                        center_candidate = X_copy[np.random.choice(np.arange(0,n_sample),1,p=pr),:]
                        flag = center_candidate in self.counter #すでに選ばれた重心なら、もう一度探索
                    self.center = center_candidate
                    
                    #距離を求める
                    ditance[:,c] = (np.sum((X-self.center[c])**2,axis=1))**0.5
                    #重心決定の確率更新
                    pr = np.sum(distance,axis=1) / np.sum(distance)
            
            old_center = np.array([np.inf, np.inf])
            while np.sum(((old_center-self.center)**2)**0.5) > 10e-7:
                self.clustering(k)
                
                old_center = self.center.copy()
                plt.figure(figsize=(5,5))
                plt.xlim(0,5)
                plt.ylim(0,5)
                plt.scatter(X[:,0], X[:,1],c=self.cluster)
                plt.scatter(self.center[:,0], self.center[:,1],s=10,c="r")
                plt.xlabel('x')
                plt.ylabel('y')
                plt.show()
                
                #重心に更新
                for i in list(set(self.cluster)):
                    self.center[i] = np.mean(X[self.cluster==i],axis=0)

# %%
kmn = kmeans()
kmn.fit(X)

# %%
a=np.array([[0,1,2,0],[1,2,0,1],[1,0,1,1]])
np.argmin(a,axis=0)
# Out:
# array([0, 2, 1, 0], dtype=int64)
